# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# So, we have our .csv files of the songs, one time with 1000, the other time with 5000 songs and what we maybe come up with later to have fun.
# Our learning platform also provides us with further information about the columns:
#
# **acousticness** - A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic. - *Float*
# **danceability** - Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.	- *Float*
# **duration_ms** - The duration of the track in milliseconds. - *Integer*
# **energy** - Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy. - *Float*
# **instrumentalness** - Predicts whether a track contains no vocals. “Ooh” and “aah” sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly “vocal”. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0. - *Float*
# **key** - The key the track is in. Integers map to pitches using standard Pitch Class notation . E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. - *Integer*
# **liveness** Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live. - *Float*
# **loudness** - The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typically range between -60 and 0 db. - *Float*
# **mode** - Mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0. - *Integer*
# **speechiness** - Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks. - *Float*
# **tempo** - The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration. - *Float*
# **time_signature** - An estimated overall time signature of a track. The time signature (meter) is a notational convention to specify how many beats are in each bar (or measure). - *Integer*
# **valence** - A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).	*Float*
#
# We now have to choose which columns are worth to keep based on these informations and our own thoughts about it and store them in a new dataframe we even might want to turn into a .csv.

# %% [markdown]
# ## **1. Importing the needed modules and .csv files**

# %%
# We want pandas and our scaler:
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import QuantileTransformer
# We keep .csv files in same path as our project so we easy navigate to them:
df_1000 = pd.read_csv(r'df_audio_features_1000.csv')
df_5000 = pd.read_csv(r'df_audio_features_5000.csv',skipinitialspace=True)

# %% [markdown]
# ## **2. Inspecting the DataFrame to Clean it**

# %%
#Basic pandas stuff:
# df_1000.info() # Put/Remove comment to read/see
# df_1000.sample(5) # Put/Remove comment to read/see
# df_5000.sample(5) # Put/Remove comment to read/see
# df_5000['duration_ms'].mean() #reasoning for smaller clusters later on...
# Out:
# 247911.1692454632

# %% [markdown]
# ### Conclusion here:
# * we want to combine artist and name into one column (might be covers on some datasets)
# * drop the other 2 columns with Dtype = object ('id','html'), we need only numbers...
# * drop 'key', 'mode', 'type', 'duration_ms', 'time_signature', since they seem meaningless for us.

# %% [markdown]
# ## **3. Preparing the data:**
# ### **3.1 1000 songs df:**

# %%
# New column 'title' to get rid of 2 objects:
df_1000['title'] = df_1000['name'] + ' - ' + df_1000['artist']
# Drop a bunch of stuff:
# df_1000.drop(['artist','name','id','html','type','duration_ms']) # cant find the freaking typo - can aswell create a sorted:
clustersongs_1000 = df_1000[['title','danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','time_signature','valence','tempo']]
# clustersongs_1000.sample(1) # See how it worked
clustersongs_1000.set_index('title', inplace=True)
# convert into (unmodified) .csv to work with in exploration:
clustersongs_1000.to_csv('1000songs.csv')

# %% [markdown]
# ### **3.2 5000 songs df**:

# %%
df_5000.columns = df_5000.columns.str.strip()
df_5000['title'] = df_5000['name'] + ' - ' + df_5000['artist']
clustersongs_5000 = df_5000[['title','danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','time_signature','valence','tempo']]
clustersongs_5000.set_index('title', inplace=True)
clustersongs_5000.to_csv('5000songs.csv')

# %% [markdown]
# ## **4. Different Scaler:**

# %% [markdown]
# ### **4.1 MinMax:**

# %%
# Taken from learning platform:
# initialize the transformer (optionally, set parameters)
my_min_max = MinMaxScaler(feature_range=(0,1)) 
# fit the transformer to the data
my_min_max.fit(clustersongs_1000)
# use the transformer to transform the data
minmax_1000_df = my_min_max.transform(clustersongs_1000) 
# reconvert the transformed data back to a DataFrame
minmax_1000 = pd.DataFrame(minmax_1000_df,
              index=clustersongs_1000.index,
              columns=clustersongs_1000.columns)
# make .csv for next notebook
minmax_1000.to_csv('1000min_max.csv')
minmax_1000.sample(5)
# Out:
#                                                     danceability    energy  \
# title
# Summertime - Charlie Parker                             0.327731  0.325287
# Dusk Till Dawn - Radio Edit - ZAYN                      0.219372  0.438744
# Mockingbird - Eminem                                    0.638434  0.680716
# A Un Paso De La Luna - Ana Mena                         0.756745  0.774092
# Turandot / Act 3: "Nessun dorma!" - Giacomo Puc...      0.167404  0.298178
#
#                                                          key  loudness  mode  \
# title
# Summertime - Charlie Parker                         0.636364  0.784924   0.0
# Dusk Till Dawn - Radio Edit - ZAYN                  1.000000  0.831219   0.0
# Mockingbird - Eminem                                0.000000  0.892660   1.0
# A Un Paso De La Luna - Ana Mena                     0.909091  0.857378   1.0
# Turandot / Act 3: "Nessun dorma!" - Giacomo Puc...  0.181818  0.700952   1.0
#
#                                                     speechiness  acousticness  \
# title
# Summertime - Charlie Parker                            0.010311      0.706827
# Dusk Till Dawn - Radio Edit - ZAYN                     0.028582      0.101404
# Mockingbird - Eminem                                   0.439219      0.209838
# A Un Paso De La Luna - Ana Mena                        0.054088      0.395581
# Turandot / Act 3: "Nessun dorma!" - Giacomo Puc...     0.030210      0.964859
#
#                                                     instrumentalness  \
# title
# Summertime - Charlie Parker                                 0.002538
# Dusk Till Dawn - Radio Edit - ZAYN                          0.000001
# Mockingbird - Eminem                                        0.000000
# A Un Paso De La Luna - Ana Mena                             0.000000
# Turandot / Act 3: "Nessun dorma!" - Giacomo Puc...          0.003716
#
#                                                     liveness  time_signature  \
# title
# Summertime - Charlie Parker                         0.190086            0.75
# Dusk Till Dawn - Radio Edit - ZAYN                  0.088458            0.75
# Mockingbird - Eminem                                0.140309            0.75
# A Un Paso De La Luna - Ana Mena                     0.281344            0.75
# Turandot / Act 3: "Nessun dorma!" - Giacomo Puc...  0.340454            0.50
#
#                                                      valence     tempo
# title
# Summertime - Charlie Parker                         0.433395  0.250102
# Dusk Till Dawn - Radio Edit - ZAYN                  0.079863  0.832273
# Mockingbird - Eminem                                0.242801  0.219315
# A Un Paso De La Luna - Ana Mena                     0.967889  0.461481
# Turandot / Act 3: "Nessun dorma!" - Giacomo Puc...  0.061840  0.185725

# %% [markdown]
# ### **4.2 Standart:**

# %%
standart = StandardScaler(with_mean=True, with_std=True).set_output(transform='pandas')
scaled_1000 = standart.fit_transform(clustersongs_1000)
scaled_1000.to_csv('1000standart.csv')
scaled_1000.sample(5)
# Out:
#                                                     danceability    energy  \
# title
# It's Only Make Believe - Single Version - Conwa...      0.014070  0.130435
# Venus - Bonus Track - Frankie Avalon                   -0.058951 -0.022145
# Your Cheatin' Heart - Hank Williams                     0.607360 -0.891496
# Straight Outta Compton - Extended Mix / Edit - ...      1.068301  1.606559
# My Band - D12                                           1.410583  1.276560
#
#                                                          key  loudness  \
# title
# It's Only Make Believe - Single Version - Conwa...  1.651308  0.630677
# Venus - Bonus Track - Frankie Avalon                1.368799 -0.221734
# Your Cheatin' Heart - Hank Williams                -1.456298 -0.076823
# Straight Outta Compton - Extended Mix / Edit - ...  0.803779  0.755951
# My Band - D12                                       0.238760  1.117011
#
#                                                         mode  speechiness  \
# title
# It's Only Make Believe - Single Version - Conwa...  0.712638    -0.555614
# Venus - Bonus Track - Frankie Avalon                0.712638    -0.657746
# Your Cheatin' Heart - Hank Williams                 0.712638    -0.675155
# Straight Outta Compton - Extended Mix / Edit - ...  0.712638     1.888602
# My Band - D12                                      -1.403236    -0.020579
#
#                                                     acousticness  \
# title
# It's Only Make Believe - Single Version - Conwa...      1.114069
# Venus - Bonus Track - Frankie Avalon                    0.350397
# Your Cheatin' Heart - Hank Williams                     0.812338
# Straight Outta Compton - Extended Mix / Edit - ...     -0.941970
# My Band - D12                                           0.000603
#
#                                                     instrumentalness  \
# title
# It's Only Make Believe - Single Version - Conwa...         -0.556894
# Venus - Bonus Track - Frankie Avalon                       -0.560124
# Your Cheatin' Heart - Hank Williams                        -0.560110
# Straight Outta Compton - Extended Mix / Edit - ...         -0.560163
# My Band - D12                                              -0.560156
#
#                                                     liveness  time_signature  \
# title
# It's Only Make Believe - Single Version - Conwa... -0.324694        0.247138
# Venus - Bonus Track - Frankie Avalon               -0.550790        0.247138
# Your Cheatin' Heart - Hank Williams                -0.633007        0.247138
# Straight Outta Compton - Extended Mix / Edit - ...  1.819789        0.247138
# My Band - D12                                      -0.468573        0.247138
#
#                                                      valence     tempo
# title
# It's Only Make Believe - Single Version - Conwa... -0.446898  0.340780
# Venus - Bonus Track - Frankie Avalon                0.853035 -0.001743
# Your Cheatin' Heart - Hank Williams                 0.752238  0.394513
# Straight Outta Compton - Extended Mix / Edit - ... -0.029807 -0.414643
# My Band - D12                                       1.402204  0.151102

# %% [markdown]
# ### **4.3 Robust:**

# %%
robust = RobustScaler(with_centering=True, with_scaling=True, quantile_range=(25.0, 75.0), copy=True, unit_variance=False).set_output(transform='pandas')
robust_1000 = robust.fit_transform(clustersongs_1000)
robust_1000.to_csv('1000robust.csv')
robust_1000.sample(5)
# Out:
#                                                     danceability    energy  \
# title
# Sweet but Psycho - Ava Max                              0.484194  0.356122
# Symphony No.3 in C Minor, Op.78, R.176 - "Organ...     -0.931380 -0.329592
# Adagio for Strings, Op. 11 - Samuel Barber             -1.350810 -1.034694
# Chantilly Lace - The Big Bopper                        -0.225135  0.564286
# Sorry - Justin Bieber                                   0.317656  0.468367
#
#                                                          key  loudness  mode  \
# title
# Sweet but Psycho - Ava Max                         -0.666667  0.455730   0.0
# Symphony No.3 in C Minor, Op.78, R.176 - "Organ... -0.833333 -0.438000   0.0
# Adagio for Strings, Op. 11 - Samuel Barber          0.833333 -2.056162  -1.0
# Chantilly Lace - The Big Bopper                    -0.333333  0.311946   0.0
# Sorry - Justin Bieber                              -0.833333  0.567081  -1.0
#
#                                                     speechiness  acousticness  \
# title
# Sweet but Psycho - Ava Max                            -0.011899     -0.445038
# Symphony No.3 in C Minor, Op.78, R.176 - "Organ...    -0.291522      0.506216
# Adagio for Strings, Op. 11 - Samuel Barber            -0.013882      0.658844
# Chantilly Lace - The Big Bopper                        0.745662      0.536742
# Sorry - Justin Bieber                                 -0.164601     -0.435372
#
#                                                     instrumentalness  \
# title
# Sweet but Psycho - Ava Max                                 -0.000795
# Symphony No.3 in C Minor, Op.78, R.176 - "Organ...          5.263681
# Adagio for Strings, Op. 11 - Samuel Barber                  4.531286
# Chantilly Lace - The Big Bopper                            -0.000610
# Sorry - Justin Bieber                                      -0.000795
#
#                                                     liveness  time_signature  \
# title
# Sweet but Psycho - Ava Max                          0.427427             0.0
# Symphony No.3 in C Minor, Op.78, R.176 - "Organ... -0.106857             0.0
# Adagio for Strings, Op. 11 - Samuel Barber          1.825467             0.0
# Chantilly Lace - The Big Bopper                    -0.439003             0.0
# Sorry - Justin Bieber                               1.736420             0.0
#
#                                                      valence     tempo
# title
# Sweet but Psycho - Ava Max                          0.299852  0.515876
# Symphony No.3 in C Minor, Op.78, R.176 - "Organ... -0.565067 -0.037175
# Adagio for Strings, Op. 11 - Samuel Barber         -0.885502 -0.684903
# Chantilly Lace - The Big Bopper                     0.925285  1.396840
# Sorry - Justin Bieber                              -0.173182 -0.224711

# %% [markdown]
# ### **4.4 Quantile:**

# %%
quantile = QuantileTransformer(n_quantiles=10, output_distribution='uniform', ignore_implicit_zeros=False, subsample=10000, random_state=None, copy=True).set_output(transform='pandas')
quantile_1000 = quantile.fit_transform(clustersongs_1000)
quantile_1000.to_csv('1000quantile.csv')
quantile_1000.sample(5)
# Out:
#                                                     danceability    energy  \
# title
# Papa Loves Mambo - Perry Como                           0.688819  0.473291
# Treat You Better - Shawn Mendes                         0.316211  0.854701
# Stand My Ground - Within Temptation                     0.139660  0.903057
# Don Giovanni, ossia Il dissoluto punito, K.527 ...      0.129630  0.073987
# Just the Way You Are - Billy Joel                       0.540098  0.428981
#
#                                                          key  loudness  mode  \
# title
# Papa Loves Mambo - Perry Como                       0.000000  0.448817   1.0
# Treat You Better - Shawn Mendes                     0.888889  0.892334   0.0
# Stand My Ground - Within Temptation                 0.444444  0.892459   0.0
# Don Giovanni, ossia Il dissoluto punito, K.527 ...  0.777778  0.102336   1.0
# Just the Way You Are - Billy Joel                   0.666667  0.509410   1.0
#
#                                                     speechiness  acousticness  \
# title
# Papa Loves Mambo - Perry Como                          0.811334      0.530752
# Treat You Better - Shawn Mendes                        0.929976      0.274894
# Stand My Ground - Within Temptation                    0.524451      0.196513
# Don Giovanni, ossia Il dissoluto punito, K.527 ...     0.516675      0.966967
# Just the Way You Are - Billy Joel                      0.291556      0.628101
#
#                                                     instrumentalness  \
# title
# Papa Loves Mambo - Perry Como                               0.335898
# Treat You Better - Shawn Mendes                             0.000000
# Stand My Ground - Within Temptation                         0.560774
# Don Giovanni, ossia Il dissoluto punito, K.527 ...          0.669288
# Just the Way You Are - Billy Joel                           0.444530
#
#                                                     liveness  time_signature  \
# title
# Papa Loves Mambo - Perry Como                       0.901140        0.555556
# Treat You Better - Shawn Mendes                     0.405458        0.555556
# Stand My Ground - Within Temptation                 0.479167        0.555556
# Don Giovanni, ossia Il dissoluto punito, K.527 ...  0.956611        1.000000
# Just the Way You Are - Billy Joel                   0.580378        0.555556
#
#                                                      valence     tempo
# title
# Papa Loves Mambo - Perry Como                       0.775571  0.136686
# Treat You Better - Shawn Mendes                     0.775571  0.154714
# Stand My Ground - Within Temptation                 0.170040  0.210566
# Don Giovanni, ossia Il dissoluto punito, K.527 ...  0.316308  0.182401
# Just the Way You Are - Billy Joel                   0.540855  0.775840

# %% [markdown]
# ### **4.5 Power:**

# %%
power = PowerTransformer(method='yeo-johnson', standardize=True, copy=True).set_output(transform='pandas')
power_1000 = power.fit_transform(clustersongs_1000)
power_1000.to_csv('1000power.csv')
power_1000.sample(5)
# Out:
#                                      danceability    energy       key  \
# title
# I Love My Bitch - Busta Rhymes           0.237663  1.119881 -1.635960
# Sister Big Stuff - John Holt             1.085018 -0.286605  0.820352
# Take A Chance On Me - ABBA               0.635718  0.633810  1.478873
# The Nights - Avicii                     -0.127344  1.219314  0.336531
# I Refuse - Shock One Remix - Netsky     -0.118088  1.097818  1.266738
#
#                                      loudness      mode  speechiness  \
# title
# I Love My Bitch - Busta Rhymes       0.745731 -1.403236     1.904774
# Sister Big Stuff - John Holt         0.296087  0.712638     1.330038
# Take A Chance On Me - ABBA           0.240003  0.712638    -1.394792
# The Nights - Avicii                  0.877451  0.712638    -0.559185
# I Refuse - Shock One Remix - Netsky  0.045914 -1.403236    -0.394452
#
#                                      acousticness  instrumentalness  liveness  \
# title
# I Love My Bitch - Busta Rhymes          -1.228796         -0.641700 -1.618637
# Sister Big Stuff - John Holt             0.374073         -0.641648 -0.782632
# Take A Chance On Me - ABBA              -0.780180         -0.641700  1.033207
# The Nights - Avicii                     -1.275469         -0.641700  1.076899
# I Refuse - Shock One Remix - Netsky     -1.334324          1.787209  1.543363
#
#                                      time_signature   valence     tempo
# title
# I Love My Bitch - Busta Rhymes             0.172232  0.759268  2.026671
# Sister Big Stuff - John Holt               0.172232  1.548285 -1.068088
# Take A Chance On Me - ABBA                 0.172232  1.529084 -0.128736
# The Nights - Avicii                        0.172232  0.645859  0.467539
# I Refuse - Shock One Remix - Netsky        0.172232 -0.586343  1.659379

# %% [markdown]
# ## **5. Different Scaler for 5000 songs:**

# %%
# Taken from above with 1000 songs:
# MinMax:
my_min_max.fit(clustersongs_5000)
minmax_5000_df = my_min_max.transform(clustersongs_5000) 
minmax_5000 = pd.DataFrame(minmax_5000_df,
              index=clustersongs_5000.index,
              columns=clustersongs_5000.columns)
minmax_5000.to_csv('5000min_max.csv')
# Standart:
scaled_5000 = standart.fit_transform(clustersongs_5000)
scaled_5000.to_csv('5000standart.csv')
# Robust:
robust_5000 = robust.fit_transform(clustersongs_5000)
robust_5000.to_csv('5000robust.csv')
# Quantile:
quantile_5000 = quantile.fit_transform(clustersongs_5000)
quantile_5000.to_csv('5000quantile.csv')
# Power:
power_5000 = power.fit_transform(clustersongs_5000)
power_5000.to_csv('5000power.csv')
