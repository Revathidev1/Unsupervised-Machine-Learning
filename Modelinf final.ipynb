# %% [markdown]
# # **Modelling**

# %% [markdown]
# ## **1. Import:**

# %%
import pandas as pd 

final_df = pd.read_csv('final5000.csv')
final_df.set_index('title', inplace=True)
final_df.columns = final_df.columns.str.strip() # thought that might fix it...

# %%
final_df
# Out:
#                                                     danceability    energy  \
# title
# Se Eu Quiser Falar Com Deus - Gilberto Gil     ...      0.699653  0.145333
# Saudade De Bahia - Antônio Carlos Jobim        ...      0.836336  0.207198
# Canta Canta, Minha Gente - Martinho Da Vila    ...      0.932164  0.495913
# Mulher Eu Sei - Chico César                    ...      0.780781  0.030722
# Rosa Morena - Kurt Elling                      ...      0.687500  0.072827
# ...                                                          ...       ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...      0.103909  0.042472
# Winter Fragments pour ensemble instrumental, so...      0.096708  0.061812
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...      0.030658  0.000569
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...      0.068416  0.012729
# Ravel: Boléro, M. 81 - Maurice Ravel           ...      0.295775  0.029804
#
# ...

# %% [markdown]
# ## **2. Sampling the different clusters:**

# %%
# Sample_df_XX = final_df.loc[final_df['cluster'] == XX] - create a df out of cluster 'XX' e.g.:

# %%
Sample_df_20= final_df.loc[final_df['cluster'] == 20]
Sample_df_20
# Out:
#                                                     danceability    energy  \
# title
# Canta Canta, Minha Gente - Martinho Da Vila    ...      0.932164  0.495913
# Ponto De Marinheiro / Marinheiro Só - Zé Mauríc...      0.885886  0.277778
# Baião Destemperado - Barbatuques               ...      0.937427  0.510899
# Canta Canta, Minha Gente - Martinho Da Vila    ...      0.825826  0.569550
# Aquele Abraço - Gilberto Gil                   ...      0.392137  0.584724
# ...                                                          ...       ...
# Nunca Estoy - C. Tangana                       ...      0.970760  0.197476
# Behold Christ The Lord - Live - Ricky Dillard  ...      0.606061  0.821759
# Never Alone - Tori Kelly                       ...      0.538012  0.301170
# Touch The Hem Of His Garment - Merry Clayton   ...      0.431111  0.316520
# He Did It - Live - The Brown Boyz              ...      0.442393  0.765233
#
# ...

# %%
Sample_df_21 = final_df.loc[final_df['cluster'] == 21]
Sample_df_21
# Out:
#                                                     danceability    energy  \
# title
# Invisible Man - The Breeders                   ...      0.284940  0.881944
# There She Goes - The La's                      ...      0.320693  0.963824
# Nosedive - Wolf Alice                          ...      0.080761  0.945736
# Freak On a Leash - Korn                        ...      0.294691  0.758065
# Laid to Rest - Lamb of God                     ...      0.301192  0.894057
# ...                                                          ...       ...
# ...And Here I Die... Satisfied - remastered 200...      0.126959  0.800926
# Corporal Celebration - Intestine Baalism       ...      0.086420  0.780093
# Manic - Monstrosity                            ...      0.248104  0.767025
# Abnormally Deceased - Only Shreds Remains Demo ...      0.080247  0.725806
# False Paradise - Megaslaughter                 ...      0.125374  0.828704
#
# ...

# %%
Sample_df_22 = final_df.loc[final_df['cluster'] == 22]
Sample_df_22
# Out:
#                                                     danceability    energy  \
# title
# País Tropical - Wilson Simonal                 ...      0.785285  0.347841
# So Nice (Summer Samba) - Marcos Valle          ...      0.882883  0.265351
# Chove Chuva - Jorge Ben Jor                    ...      0.794294  0.235380
# Augusta, Angélica e Consolação - Tom Zé        ...      0.696181  0.196593
# Preta Pretinha - Novos Baianos                 ...      0.779279  0.315789
# ...                                                          ...       ...
# You Get The Glory - Jonathan Traylor           ...      0.248104  0.184220
# Faith That Conquers - Kelly Price              ...      0.271939  0.209407
# Fear Is Not Welcome - Brian Courtney Wilson    ...      0.476608  0.243421
# For Your Glory - 1 Mic 1 Take - Tasha Cobbs Leo...      0.365470  0.199244
# There Is More - Lexi                           ...      0.563973  0.252193
#
# ...

# %%
Sample_df_23 = final_df.loc[final_df['cluster'] == 23]
Sample_df_23
# Out:
#                                                     danceability    energy  \
# title
# Saudade De Bahia - Antônio Carlos Jobim        ...      0.836336  0.207198
# Carnaval Inesquecível Na Cidade Alta - Mundo Li...      0.842342  0.312865
# Bossa Dorado - Pete Krebs & The Kung Pao Chi   ...      0.890643  0.231725
# Esperando Na Janela - Versão Acústica - Gilbert...      0.626263  0.096083
# Algo Novo - Deolinda                           ...      0.919883  0.221338
# ...                                                          ...       ...
# Kogong - Mark Forster                          ...      0.701389  0.288743
# Vagabund - Bausa                               ...      0.957310  0.312865
# Nie allein - TEY                               ...      0.718750  0.383074
# The Victory Song - Live - Joyous Celebration   ...      0.803303  0.326023
# The Potter's House - Jerard & Jovaun           ...      0.604377  0.315058
#
# ...

# %%
Sample_df_24= final_df.loc[final_df['cluster'] == 24]
Sample_df_24
# Out:
#                                                     danceability    energy  \
# title
# Pobre e Rico - Batida                          ...      0.888889  0.747312
# Les Dones Macabres - Nico Roig                 ...      0.478070  0.660597
# Game Of Pricks - Guided By Voices              ...      0.270856  0.700717
# Inbetween Days - The Cure                      ...      0.495614  0.784722
# Faithless - B-Side - City and Colour           ...      0.309859  0.930233
# ...                                                          ...       ...
# Als wär's das erste Mal - Unheilig             ...      0.641414  0.639353
# Caramelo - Ozuna                               ...      0.815315  0.604451
# Baila Conmigo (feat. Kelly Ruiz) - Dayvi       ...      0.840841  0.927649
# Just Like God - Evvie McKinney                 ...      0.369573  0.532698
# Put A Praise On It - Live - Tasha Cobbs Leonard...      0.438291  0.891473
#
# ...

# %%
Sample_df_25= final_df.loc[final_df['cluster'] == 25]
Sample_df_25
# Out:
#                                                     danceability    energy  \
# title
# Brigas Nunca Mais                              ...      0.762153  0.304825
# Rosa Morena - Live At Carnegie Hall/1964       ...      0.491228  0.082007
# O Pato (The Duck) - Live At Carnegie Hall/1964 ...      0.636364  0.110159
# A Prosa Impúrpura do Caicó                     ...      0.456140  0.123239
# Tanto Mar                                      ...      0.372650  0.274123
# ...                                                          ...       ...
# Nein Mann - Radio Edit                         ...      0.973099  0.383074
# Eiserner Steg                                  ...      0.646465  0.315789
# Wie soll ein Mensch das ertragen               ...      0.517544  0.212501
# Unter meiner Haut - Radio Mix                  ...      0.895322  0.399655
# Du bist schön                                  ...      0.723958  0.427634
#
# ...

# %%
Sample_df_26= final_df.loc[final_df['cluster'] == 26]
Sample_df_26
# Out:
#                                                     danceability    energy  \
# title
# Desafinado - Stan Getz                         ...      0.412650  0.089351
# Insensatez - Stan Getz                         ...      0.720486  0.113517
# Para Machuchar Meu Coracao - Stan Getz         ...      0.629630  0.080171
# Quando Te Vi - Luisa Sobral                    ...      0.511696  0.078947
# Sr. Vinho - Luisa Sobral                       ...      0.289274  0.179801
# ...                                                          ...       ...
# The Planets - Suite for large orchestra, Op.32:...      0.101852  0.161683
# Symphonia: Sum Fluxae Pretium Spei: 2. Adagio t...      0.095679  0.039718
# Stravinsky: Symphony in C: I. Moderato alla bre...      0.301192  0.019645
# Du cristal - Kaija Saariaho                    ...      0.082305  0.120145
# Don Giovanni, K.527: Overture - Wolfgang Amadeu...      0.334701  0.106487
#
# ...

# %%
Sample_df_27= final_df.loc[final_df['cluster'] == 27]
Sample_df_27
# Out:
#                                                     danceability    energy  \
# title
# Come Saturday - The Pains Of Being Pure At Hear...      0.083848  0.844907
# Objecte Pur - Isaac Ulam                       ...      0.383932  0.932817
# Cali in a Cup - Woods                          ...      0.144392  0.659079
# All In One - Bob Marley & The Wailers          ...      0.138052  0.831019
# Ballistic Affair - Leroy Smart                 ...      0.557239  0.301901
# ...                                                          ...       ...
# The Truth Begins Where Man Stops to Think - Aga...      0.103395  0.888889
# Infernal - Defaced Creation                    ...      0.198274  0.865741
# Ancient Slumber - Necrophagia                  ...      0.280607  0.389292
# The Exorcist - Cannibal Corpse                 ...      0.060185  0.872685
# Infection Of Death - Baphomet                  ...      0.149146  0.646940
#
# ...

# %%
Sample_df_28= final_df.loc[final_df['cluster'] == 28]
Sample_df_28
# Out:
#                                                     danceability    energy  \
# title
# Aguas De Março - Tempo Rei                     ...      0.900585  0.212501
# Rosa, Menina Rosa - Jorge Ben Jor              ...      0.574074  0.391364
# Nomes de Favela - Moyseis Marques              ...      0.852853  0.282895
# Waddlin Around - The King Khan & BBQ Show      ...      0.931579  0.330409
# Cinnamon - Palehound                           ...      0.902339  0.774194
# ...                                                          ...       ...
# Downtown - Anitta                              ...      0.885886  0.430743
# High Up - Jonathan Traylor                     ...      0.806306  0.239766
# Dance Party - Kelly Price                      ...      0.744792  0.702509
# Man On Fire - Idahams                          ...      0.881381  0.439033
# If He Did It Before....Same God - Live - Tye Tr...      0.614478  0.580172
#
# ...

# %%
Sample_df_29= final_df.loc[final_df['cluster'] == 29]
Sample_df_29
# Out:
#                                                     danceability    energy  \
# title
# Águas De Março - Antônio Carlos Jobim          ...      0.666667  0.309211
# Xico - Luisa Sobral                            ...      0.388034  0.315058
# Vai (Menina amanhã de manhã) - Tom Zé          ...      0.722222  0.379965
# Clouds - The Go-Betweens                       ...      0.341880  0.657562
# Inspector Norse - Todd Terje                   ...      0.599327  0.220897
# ...                                                          ...       ...
# Zorra - Bad Gyal                               ...      0.663300  0.400691
# Happy - Live/Remastered - Tasha Cobbs Leonard  ...      0.345983  0.734767
# A Great Work - Brian Courtney Wilson           ...      0.405470  0.351986
# Worth Fighting For - Live - Brian Courtney Wils...      0.218877  0.269006
# Just As Sure - Tori Kelly                      ...      0.560606  0.316520
#
# ...

# %% [markdown]
# ## **3. Manual Labelling:**

# %% [markdown]
# Cluster 20: Hip hop
# Cluster 21: Rock style Thrash
# Cluster 22: Jazz(Bossanova)
# Cluster 23: Gypsy Jazz
# Cluster 24: Gospel music
# Cluster 25: Go-go subgenre of funk music
# Cluster 26: Classical
# Cluster 27: Lo-Fi music
# Cluster 28: Death metal
# Cluster 29: Funk/Soul
